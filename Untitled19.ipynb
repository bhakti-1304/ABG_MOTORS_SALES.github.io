# %% [markdown]
# <a href="https://colab.research.google.com/github/bhakti-1304/ABG_MOTORS_SALES.github.io/blob/main/Untitled19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#indian_data_path = "/Indian_Dataset_Cleaned.xlsx"
#japanese_data_path = "/Japanese_Dataset_Cleaned.xlsx"

indian_df = pd.read_excel('/content/Indian_Dataset_Cleaned.xlsx')
japanese_df = pd.read_excel('/content/Japanese_Dataset_Cleaned.xlsx')

# Selecting numerical columns only
num_cols_indian = indian_df.select_dtypes(include=["number"])
num_cols_japanese = japanese_df.select_dtypes(include=["number"])

# Boxplot to visualize outliers
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.boxplot(data=num_cols_indian)
plt.title("Indian Dataset - Boxplot")

plt.subplot(1, 2, 2)
sns.boxplot(data=num_cols_japanese)
plt.title("Japanese Dataset - Boxplot")

plt.xticks(rotation=90)
plt.show()

# IQR Method to detect outliers
def detect_outliers_iqr(df):
    outlier_counts = {}
    for col in df.columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
        outlier_counts[col] = outliers.shape[0]
    return outlier_counts

outliers_indian = detect_outliers_iqr(num_cols_indian)
outliers_japanese = detect_outliers_iqr(num_cols_japanese)

print("\n📊 Outliers Count in Indian Dataset:")
print(outliers_indian)

print("\n📊 Outliers Count in Japanese Dataset:")
print(outliers_japanese)
# Out:
# 📊 Outliers Count in Indian Dataset:
# {'CURR_AGE': 0, 'ANN_INCOME': 0}
#
# 📊 Outliers Count in Japanese Dataset:
# {'CURR_AGE': 0, 'ANN_INCOME': 0, 'PURCHASE': 0, 'AGE_CAR_YEARS': 2638}

# %%
# Handling outliers in the 'AGE_CAR_YEARS' feature for Japanese dataset

# Calculating the Q1, Q3, and IQR for 'AGE_CAR_YEARS' column
Q1 = japanese_df['AGE_CAR_YEARS'].quantile(0.25)
Q3 = japanese_df['AGE_CAR_YEARS'].quantile(0.75)
IQR = Q3 - Q1

# Defining lower and upper bounds for 'AGE_CAR_YEARS' feature
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Capping the values of 'AGE_CAR_YEARS' to the bounds
japanese_df['AGE_CAR_YEARS'] = japanese_df['AGE_CAR_YEARS'].clip(lower=lower_bound, upper=upper_bound)

# Checking the number of remaining outliers after handling
remaining_outliers = ((japanese_df['AGE_CAR_YEARS'] < lower_bound) | (japanese_df['AGE_CAR_YEARS'] > upper_bound)).sum()
print(f"\nRemaining outliers in 'AGE_CAR_YEARS' after handling: {remaining_outliers}")
# Out:
# Remaining outliers in 'AGE_CAR_YEARS' after handling: 0

# %%
#importing libraries
import seaborn as sns
import matplotlib.pyplot as plt

# %%
print(indian_df.shape)
print(japanese_df.shape)
# Out:
# (70000, 5)
# (40000, 6)

# %%
#summary statistics
print("\nIndian Dataset Summary Statistics:")
print(indian_df.describe())

print("\nJapanese Dataset Summary Statistics:")
print(japanese_df.describe())
# Out:
# Indian Dataset Summary Statistics:
#            CURR_AGE    ANN_INCOME                       DT_MAINT
# count  70000.000000  7.000000e+04                          70000
# mean      44.995314  1.148679e+06  2018-06-28 16:10:28.662856960
# min       25.000000  3.000330e+05            2016-09-14 00:00:00
# 25%       35.000000  8.568238e+05            2018-03-15 00:00:00
# 50%       45.000000  1.125152e+06            2018-07-26 00:00:00
# 75%       55.000000  1.438676e+06            2018-12-24 00:00:00
# max       65.000000  1.999989e+06            2019-06-30 00:00:00
# std       11.822122  3.994505e+05                            NaN
#
# Japanese Dataset Summary Statistics:
#           CURR_AGE     ANN_INCOME      PURCHASE  AGE_CAR_YEARS
# count  40000.00000   40000.000000  40000.000000   40000.000000
# mean      44.99745  359398.878225      0.575775       0.960335
# std       11.82008  175109.260472      0.494231       0.496044
# min       25.00000   70089.000000      0.000000       0.000000
# 25%       35.00000  219766.000000      0.000000       0.640000
# 50%       45.00000  337657.000000      1.000000       0.910000
# 75%       55.00000  464260.750000      1.000000       1.220000
# max       65.00000  799971.000000      1.000000       2.090000

# %%
#gender distribution in japanese dataset
sns.catplot(data=japanese_df, x="GENDER", kind="count")
plt.title("Gender Distribution in Japanese Dataset")
plt.show()

# %%
#gender distribution in indian dataset
sns.catplot(data=indian_df, x="GENDER", kind="count")
plt.title("Gender Distribution in Indian Dataset")
plt.show()

# %%
#select numerical columns for analysis
num_cols_indian = indian_df.select_dtypes(include=["number"])
num_cols_japanese = japanese_df.select_dtypes(include=["number"])

# %%
# Plot distributions for Indian dataset (first 4 numerical columns)
plt.figure(figsize=(12, 6))
for i, col in enumerate(num_cols_indian.columns[:4]):
    plt.subplot(2, 2, i + 1)
    sns.histplot(indian_df[col], kde=True, bins=30)
    plt.title(f"Distribution of {col} (Indian Dataset)")
plt.tight_layout()
plt.show()

# %%
# Plot distributions for Japanese dataset (first 4 numerical columns)
plt.figure(figsize=(12, 6))
for i, col in enumerate(num_cols_japanese.columns[:4]):
    plt.subplot(2, 2, i + 1)
    sns.histplot(japanese_df[col], kde=True, bins=30)
    plt.title(f"Distribution of {col} (Japanese Dataset)")
plt.tight_layout()
plt.show()

# %%
# Correlation heatmap for Indian dataset
plt.figure(figsize=(10, 6))
sns.heatmap(num_cols_indian.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Matrix - Indian Dataset")
plt.show()

# %%
# Correlation heatmap for Japanese dataset
plt.figure(figsize=(10, 6))
sns.heatmap(num_cols_japanese.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Matrix - Japanese Dataset")
plt.show()

# %%
indian_df.to_excel("/content/Indian_Dataset_Cleaned_v2.xlsx", index=False)
japanese_df.to_excel("/content/Japanese_Dataset_Cleaned_v2.xlsx", index=False)

print("\n✅ EDA and Outlier Handling Completed. Cleaned files saved.")
# Out:
# ✅ EDA and Outlier Handling Completed. Cleaned files saved.

# %% [markdown]
# <h3>Feature Engineering </h3>

# %%
ind = pd.read_excel("/content/Indian_Dataset_Cleaned_v2.xlsx")
jap = pd.read_excel("/content/Japanese_Dataset_Cleaned_v2.xlsx")

# %%
print(ind.head())
print(jap.head())
# Out:
#            ID  CURR_AGE GENDER  ANN_INCOME   DT_MAINT
# 0  20710B05XL        54      M     1425390 2018-04-20
# 1  89602T51HX        47      M     1678954 2018-06-08
# 2  70190Z52IP        60      M      931624 2017-07-31
# 3  25623V15MU        55      F     1106320 2017-07-31
# 4  36230I68CE        32      F      748465 2019-01-27
#            ID  CURR_AGE GENDER  ANN_INCOME  PURCHASE  AGE_CAR_YEARS
# 0  00001Q15YJ        50      M      445344         0           1.20
# 1  00003I71CQ        35      M      107634         0           0.78
# 2  00003N47FS        59      F      502787         1           1.07
# 3  00005H41DE        43      M      585664         0           1.30
# 4  00007E17UM        39      F      705723         1           1.36

# %%
# Converting DT_MAINT col to similar as AGE_CAR_YEARS

# Convert DT_MAINT to datetime format
ind["DT_MAINT"] = pd.to_datetime(ind["DT_MAINT"], errors="coerce")  # Handle errors safely

# Set reference date to 2020-01-01
ref_date = pd.to_datetime("2020-01-01")

# Compute years since last maintenance
ind["MAINT_YEARS_AGO"] = (ref_date - ind["DT_MAINT"]).dt.days / 365

# Round for readability
ind["MAINT_YEARS_AGO"] = ind["MAINT_YEARS_AGO"].round(2)

print(ind.head())
# Out:
#            ID  CURR_AGE GENDER  ANN_INCOME   DT_MAINT  MAINT_YEARS_AGO
# 0  20710B05XL        54      M     1425390 2018-04-20             1.70
# 1  89602T51HX        47      M     1678954 2018-06-08             1.57
# 2  70190Z52IP        60      M      931624 2017-07-31             2.42
# 3  25623V15MU        55      F     1106320 2017-07-31             2.42
# 4  36230I68CE        32      F      748465 2019-01-27             0.93

# %%
# Rename AGE_CAR_YEARS in jap dataset to MAINT_YEARS_AGO for consistency
jap.rename(columns={"AGE_CAR_YEARS": "MAINT_YEARS_AGO"}, inplace=True)

print(jap.head())
# Out:
#            ID  CURR_AGE GENDER  ANN_INCOME  PURCHASE  MAINT_YEARS_AGO
# 0  00001Q15YJ        50      M      445344         0             1.20
# 1  00003I71CQ        35      M      107634         0             0.78
# 2  00003N47FS        59      F      502787         1             1.07
# 3  00005H41DE        43      M      585664         0             1.30
# 4  00007E17UM        39      F      705723         1             1.36

# %% [markdown]
# Handling Categorical Variables

# %%
# Encoding 'GENDER' column (0 for Female, 1 for Male)
ind["GENDER_ENCODED"] = ind["GENDER"].map({"M": 1, "F": 0})
jap["GENDER_ENCODED"] = jap["GENDER"].map({"M": 1, "F": 0})

# Define income brackets for 'ind'
ind_income_bins = [0, ind["ANN_INCOME"].quantile(0.33), ind["ANN_INCOME"].quantile(0.66), ind["ANN_INCOME"].max()]
ind["INCOME_BRACKET"] = pd.cut(ind["ANN_INCOME"], bins=ind_income_bins, labels=["Low", "Medium", "High"])

# Define income brackets for 'jap'
jap_income_bins = [0, jap["ANN_INCOME"].quantile(0.33), jap["ANN_INCOME"].quantile(0.66), jap["ANN_INCOME"].max()]
jap["INCOME_BRACKET"] = pd.cut(jap["ANN_INCOME"], bins=jap_income_bins, labels=["Low", "Medium", "High"])

# Display first 5 rows to verify changes
print(ind[["GENDER", "GENDER_ENCODED", "INCOME_BRACKET"]].head())
print(jap[["GENDER", "GENDER_ENCODED", "INCOME_BRACKET"]].head())
# Out:
#   GENDER  GENDER_ENCODED INCOME_BRACKET
# 0      M               1           High
# 1      M               1           High
# 2      M               1            Low
# 3      F               0         Medium
# 4      F               0            Low
#   GENDER  GENDER_ENCODED INCOME_BRACKET
# 0      M               1           High
# 1      M               1            Low
# 2      F               0           High
# 3      M               1           High
# 4      F               0           High

# %% [markdown]
# Scaling Numerical Features

# %%
from sklearn.preprocessing import MinMaxScaler

# Define the numerical features (same for both datasets now)
num_features = ["ANN_INCOME", "MAINT_YEARS_AGO"]

# Initialize the scaler
scaler = MinMaxScaler()

# Apply scaling
ind[num_features] = scaler.fit_transform(ind[num_features])
jap[num_features] = scaler.fit_transform(jap[num_features])

# Display first 5 rows to verify changes
print(ind[num_features].head())
print(jap[num_features].head())
# Out:
#    ANN_INCOME  MAINT_YEARS_AGO
# 0    0.661992         0.426523
# 1    0.811151         0.379928
# 2    0.371534         0.684588
# 3    0.474299         0.684588
# 4    0.263790         0.150538
#    ANN_INCOME  MAINT_YEARS_AGO
# 0    0.514131         0.574163
# 1    0.051440         0.373206
# 2    0.592833         0.511962
# 3    0.706381         0.622010
# 4    0.870872         0.650718

# %%
import seaborn as sns
sns.boxplot(x=ind["MAINT_YEARS_AGO"])
# Out:
# <Axes: xlabel='MAINT_YEARS_AGO'>

# %%
import numpy as np

# Find the 99th percentile
upper_limit = ind["MAINT_YEARS_AGO"].quantile(0.99)

# Cap values above this threshold
ind["MAINT_YEARS_AGO"] = np.where(ind["MAINT_YEARS_AGO"] > upper_limit, upper_limit, ind["MAINT_YEARS_AGO"])
jap["MAINT_YEARS_AGO"] = np.where(jap["MAINT_YEARS_AGO"] > upper_limit, upper_limit, jap["MAINT_YEARS_AGO"])

# %%
# Calculate Q1 (25th percentile) and Q3 (75th percentile)
Q1_ind = ind["MAINT_YEARS_AGO"].quantile(0.25)
Q3_ind = ind["MAINT_YEARS_AGO"].quantile(0.75)
IQR_ind = Q3_ind - Q1_ind

# %%
# Define bounds for outliers
lower_bound_ind = Q1_ind - 1.5 * IQR_ind
upper_bound_ind = Q3_ind + 1.5 * IQR_ind

# %%
ind["MAINT_YEARS_AGO"] = ind["MAINT_YEARS_AGO"].clip(lower=lower_bound_ind, upper=upper_bound_ind)

# %%
# Calculate Q1 (25th percentile) and Q3 (75th percentile)
Q1_ind = ind["MAINT_YEARS_AGO"].quantile(0.25)
Q3_ind = ind["MAINT_YEARS_AGO"].quantile(0.75)
IQR_ind = Q3_ind - Q1_ind

Q1_jap = jap["MAINT_YEARS_AGO"].quantile(0.25)
Q3_jap = jap["MAINT_YEARS_AGO"].quantile(0.75)
IQR_jap = Q3_jap - Q1_jap

# Define bounds for outliers
lower_bound_ind = Q1_ind - 1.5 * IQR_ind
upper_bound_ind = Q3_ind + 1.5 * IQR_ind

lower_bound_jap = Q1_jap - 1.5 * IQR_jap
upper_bound_jap = Q3_jap + 1.5 * IQR_jap

# Count outliers
outliers_ind = ((ind["MAINT_YEARS_AGO"] < lower_bound_ind) | (ind["MAINT_YEARS_AGO"] > upper_bound_ind)).sum()
outliers_jap = ((jap["MAINT_YEARS_AGO"] < lower_bound_jap) | (jap["MAINT_YEARS_AGO"] > upper_bound_jap)).sum()

print(f"Number of outliers in IND dataset: {outliers_ind}")
print(f"Number of outliers in JAP dataset: {outliers_jap}")
# Out:
# Number of outliers in IND dataset: 0
# Number of outliers in JAP dataset: 0

# %%
# Verify after capping
sns.boxplot(x=ind["MAINT_YEARS_AGO"])
plt.show()

# %% [markdown]
# Feature Interaction

# %%
# Feature Engineering
ind["INCOME_PER_YEAR"] = ind["ANN_INCOME"] / (ind["MAINT_YEARS_AGO"] + 1)
ind["AGE_MAINT_RATIO"] = ind["CURR_AGE"] / (ind["MAINT_YEARS_AGO"] + 1)

jap["INCOME_PER_YEAR"] = jap["ANN_INCOME"] / (jap["MAINT_YEARS_AGO"] + 1)
jap["AGE_MAINT_RATIO"] = jap["CURR_AGE"] / (jap["MAINT_YEARS_AGO"] + 1)

# Check new features
print(ind[["INCOME_PER_YEAR", "AGE_MAINT_RATIO"]].head())
print(jap[["INCOME_PER_YEAR", "AGE_MAINT_RATIO"]].head())
# Out:
#    INCOME_PER_YEAR  AGE_MAINT_RATIO
# 0         0.464060        37.854271
# 1         0.587821        34.059740
# 2         0.220549        35.617021
# 3         0.281552        32.648936
# 4         0.229276        27.813084
#    INCOME_PER_YEAR  AGE_MAINT_RATIO
# 0         0.326606        31.762918
# 1         0.037460        25.487805
# 2         0.392095        39.022152
# 3         0.435498        26.510324
# 4         0.527572        23.626087

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# Selecting numerical features
num_features = ["INCOME_PER_YEAR", "AGE_MAINT_RATIO"]

# Apply scaling
ind[num_features] = scaler.fit_transform(ind[num_features])
jap[num_features] = scaler.transform(jap[num_features])

# Check scaled values
print(ind[num_features].head())
print(jap[num_features].head())
# Out:
#    INCOME_PER_YEAR  AGE_MAINT_RATIO
# 0         0.450513         0.355960
# 1         1.101099        -0.003056
# 2        -0.829570         0.144285
# 3        -0.508890        -0.136537
# 4        -0.783694        -0.594076
#    INCOME_PER_YEAR  AGE_MAINT_RATIO
# 0        -0.272050        -0.220367
# 1        -1.792028        -0.814079
# 2         0.072211         0.466457
# 3         0.300369        -0.717335
# 4         0.784383        -0.990224

# %% [markdown]
# Feature Selection

# %%
jap.head()
# Out:
#            ID  CURR_AGE GENDER  ANN_INCOME  PURCHASE  MAINT_YEARS_AGO  \
# 0  00001Q15YJ        50      M    0.514131         0         0.574163
# 1  00003I71CQ        35      M    0.051440         0         0.373206
# 2  00003N47FS        59      F    0.592833         1         0.511962
# 3  00005H41DE        43      M    0.706381         0         0.622010
# 4  00007E17UM        39      F    0.870872         1         0.650718
#
#    GENDER_ENCODED INCOME_BRACKET  INCOME_PER_YEAR  AGE_MAINT_RATIO
# 0               1           High        -0.272050        -0.220367
# 1               1            Low        -1.792028        -0.814079
# 2               0           High         0.072211         0.466457
# 3               1           High         0.300369        -0.717335
# 4               0           High         0.784383        -0.990224

# %%
# Drop unnecessary columns, checking if they exist first
drop_cols_ind = ["ID", "GENDER", "INCOME_BRACKET", "DT_MAINT"]
existing_cols_ind = [col for col in drop_cols_ind if col in ind.columns]
ind.drop(columns=existing_cols_ind, inplace=True)

drop_cols_jap = ["ID", "GENDER", "INCOME_BRACKET"]
existing_cols_jap = [col for col in drop_cols_jap if col in jap.columns]
jap.drop(columns=existing_cols_jap, inplace=True)

# Verify changes
print(ind.head())
print(jap.head())
# Out:
#    CURR_AGE  ANN_INCOME  MAINT_YEARS_AGO  GENDER_ENCODED  INCOME_PER_YEAR  \
# 0        54    0.661992         0.426523               1         0.450513
# 1        47    0.811151         0.379928               1         1.101099
# 2        60    0.371534         0.684588               1        -0.829570
# 3        55    0.474299         0.684588               0        -0.508890
# 4        32    0.263790         0.150538               0        -0.783694
#
#    AGE_MAINT_RATIO
# 0         0.355960
# 1        -0.003056
# 2         0.144285
# 3        -0.136537
# 4        -0.594076
#    CURR_AGE  ANN_INCOME  PURCHASE  MAINT_YEARS_AGO  GENDER_ENCODED  \
# 0        50    0.514131         0         0.574163               1
# 1        35    0.051440         0         0.373206               1
# 2        59    0.592833         1         0.511962               0
# 3        43    0.706381         0         0.622010               1
# 4        39    0.870872         1         0.650718               0
#
#    INCOME_PER_YEAR  AGE_MAINT_RATIO
# 0        -0.272050        -0.220367
# 1        -1.792028        -0.814079
# 2         0.072211         0.466457
# 3         0.300369        -0.717335
# 4         0.784383        -0.990224

# %%
# Correlation Analysis (for numerical features)
import seaborn as sns
import matplotlib.pyplot as plt

# Compute correlation matrix
corr_matrix = ind.corr()

# Plot heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Feature Correlation Heatmap (IND)")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Compute correlation matrix
corr_matrix = jap.corr()

# Plot heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Feature Correlation Heatmap (JAP)")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Drop redundant features
drop_cols = ["ANN_INCOME", "AGE_MAINT_RATIO"]
ind_cleaned = ind.drop(columns=drop_cols)
jap_cleaned = jap.drop(columns=drop_cols)

# Combine both datasets
combined_df = pd.concat([ind_cleaned, jap_cleaned], ignore_index=True)

# Compute correlation matrix
corr_matrix = combined_df.corr()

# Plot heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Feature Correlation Heatmap (Combined)")
plt.show()

# %%
ind.head()
# Out:
#    CURR_AGE  ANN_INCOME  MAINT_YEARS_AGO  GENDER_ENCODED  INCOME_PER_YEAR  \
# 0        54    0.661992         0.426523               1         0.450513
# 1        47    0.811151         0.379928               1         1.101099
# 2        60    0.371534         0.684588               1        -0.829570
# 3        55    0.474299         0.684588               0        -0.508890
# 4        32    0.263790         0.150538               0        -0.783694
#
#    AGE_MAINT_RATIO
# 0         0.355960
# 1        -0.003056
# 2         0.144285
# 3        -0.136537
# 4        -0.594076

# %%
jap.head()
# Out:
#    CURR_AGE  ANN_INCOME  PURCHASE  MAINT_YEARS_AGO  GENDER_ENCODED  \
# 0        50    0.514131         0         0.574163               1
# 1        35    0.051440         0         0.373206               1
# 2        59    0.592833         1         0.511962               0
# 3        43    0.706381         0         0.622010               1
# 4        39    0.870872         1         0.650718               0
#
#    INCOME_PER_YEAR  AGE_MAINT_RATIO
# 0        -0.272050        -0.220367
# 1        -1.792028        -0.814079
# 2         0.072211         0.466457
# 3         0.300369        -0.717335
# 4         0.784383        -0.990224

# %%
import pandas as pd

# Define file paths for separate Excel files
india_file_path = "Indian_Dataset_Scaled.xlsx"
japan_file_path = "Japanese_Dataset_Scaled.xlsx"

# Export each dataset to a separate Excel file
ind.to_excel(india_file_path, index=False)
jap.to_excel(japan_file_path, index=False)

print(f"Datasets successfully exported to separate files:\n- {india_file_path}\n- {japan_file_path}")
# Out:
# Datasets successfully exported to separate files:
# - Indian_Dataset_Scaled.xlsx
# - Japanese_Dataset_Scaled.xlsx

# %% [markdown]
# Model Building and Training

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import accuracy_score, classification_report
import xgboost as xgb

# %%
# Load datasets
japanese_df = pd.read_excel("/content/Japanese_Dataset_Scaled.xlsx")  # Training dataset
indian_df = pd.read_excel("/content/Indian_Dataset_Scaled.xlsx")  # Test dataset (without purchase column)

# Drop missing values
japanese_df.dropna(inplace=True)
indian_df.dropna(inplace=True)

# %%
# Separate features and target variable
X = japanese_df.drop(columns=["PURCHASE"])
y = japanese_df["PURCHASE"]

# %%
# Apply RobustScaler for handling outliers
scaler = RobustScaler()
X_scaled = scaler.fit_transform(X)
indian_scaled = scaler.transform(indian_df)  # Scale Indian dataset similarly

# Convert back to DataFrame
X_scaled = pd.DataFrame(X_scaled, columns=X.columns)
indian_scaled = pd.DataFrame(indian_scaled, columns=indian_df.columns)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Confirm dataset shapes
print("\nTraining Data Shape:", X_train.shape)
print("Testing Data Shape:", X_test.shape)
print("Indian City Data Shape:", indian_scaled.shape)
# Out:
# Training Data Shape: (32000, 6)
# Testing Data Shape: (8000, 6)
# Indian City Data Shape: (70000, 6)

# %%
# Initialize XGBoost model
xgb_model = xgb.XGBClassifier(
    n_estimators=200,
    learning_rate=0.05,
    max_depth=6,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42
)

# Train the model
xgb_model.fit(X_train, y_train)

# Make predictions
y_pred = xgb_model.predict(X_test)

# Evaluate performance
print("\nXGBoost Model Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# XGBoost Model Accuracy: 0.699
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.63      0.66      0.65      3349
#            1       0.75      0.72      0.74      4651
#
#     accuracy                           0.70      8000
#    macro avg       0.69      0.69      0.69      8000
# weighted avg       0.70      0.70      0.70      8000

# %%
# Get feature importance from XGBoost
xgb_importance = pd.Series(xgb_model.feature_importances_, index=X.columns)

# Plot feature importance
plt.figure(figsize=(10, 5))
xgb_importance.sort_values(ascending=False).plot(kind='bar', title="XGBoost Feature Importance")
plt.show()

# %% [markdown]
# Hyperparameter Tuning

# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.3.0-py3-none-any.whl.metadata (17 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.15.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.40)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.13.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.0)
# Downloading optuna-4.3.0-py3-none-any.whl (386 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.6/386.6 kB 14.4 MB/s eta 0:00:00
# Downloading alembic-1.15.2-py3-none-any.whl (231 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.9/231.9 kB 15.4 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, alembic, optuna
# Successfully installed alembic-1.15.2 colorlog-6.9.0 optuna-4.3.0

# %%
import optuna

def objective(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 500),
        'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.2),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
        'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
        'random_state': 42
    }
    model = xgb.XGBClassifier(**params)
    model.fit(X_train, y_train)
    return accuracy_score(y_test, model.predict(X_test))

# Run Optuna optimization
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=30)  # Run 30 trials

# Get best parameters
best_params = study.best_params
print("\nBest XGBoost Parameters:", best_params)

# Train final model with best parameters
final_xgb_model = xgb.XGBClassifier(**best_params)
final_xgb_model.fit(X_train, y_train)

# Evaluate performance
y_pred_final = final_xgb_model.predict(X_test)
print("\nFinal XGBoost Model Accuracy:", accuracy_score(y_test, y_pred_final))
print("\nClassification Report:\n", classification_report(y_test, y_pred_final))
# Out:
# [I 2025-04-22 08:00:53,867] A new study created in memory with name: no-name-4394df08-e273-4114-b71f-10e9b4b0ae92
# <ipython-input-46-7f746f6fccb6>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.2),
# <ipython-input-46-7f746f6fccb6>:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# <ipython-input-46-7f746f6fccb6>:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# [I 2025-04-22 08:01:03,328] Trial 0 finished with value: 0.691125 and parameters: {'n_estimators': 328, 'learning_rate': 0.04731797974698248, 'max_depth': 7, 'subsample': 0.6709170989532857, 'colsample_bytree': 0.7476381490357074}. Best is trial 0 with value: 0.691125.
# <ipython-input-46-7f746f6fccb6>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.2),
# <ipython-input-46-7f746f6fccb6>:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# <ipython-input-46-7f746f6fccb6>:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# [I 2025-04-22 08:01:14,746] Trial 1 finished with value: 0.68425 and parameters: {'n_estimators': 166, 'learning_rate': 0.08005677464884373, 'max_depth': 10, 'subsample': 0.6446633859655364, 'colsample_bytree': 0.756394434142645}. Best is trial 0 with value: 0.691125.
# <ipython-input-46-7f746f6fccb6>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.2),
# <ipython-input-46-7f746f6fccb6>:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# <ipython-input-46-7f746f6fccb6>:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# [I 2025-04-22 08:01:17,165] Trial 2 finished with value: 0.698 and parameters: {'n_estimators': 396, 'learning_rate': 0.018213911793047998, 'max_depth': 6, 'subsample': 0.6339555522493228, 'colsample_bytree': 0.7820978309115996}. Best is trial 2 with value: 0.698.
# <ipython-input-46-7f746f6fccb6>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.2),
# <ipython-input-46-7f746f6fccb6>:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# <ipython-input-46-7f746f6fccb6>:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# [I 2025-04-22 08:01:29,125] Trial 3 finished with value: 0.686125 and parameters: {'n_estimators': 414, 'learning_rate': 0.050832013661535905, 'max_depth': 9, 'subsample': 0.7466613485563831, 'colsample_bytree': 0.9358100585267058}. Best is trial 2 with value: 0.698.
# <ipython-input-46-7f746f6fccb6>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.2),
# <ipython-input-46-7f746f6fccb6>:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# <ipython-input-46-7f746f6fccb6>:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# [I 2025-04-22 08:02:06,885] Trial 4 finished with value: 0.689 and parameters: {'n_estimators': 368, 'learning_rate': 0.02614826148715566, 'max_depth': 10, 'subsample': 0.6712030824494337, 'colsample_bytree': 0.7114769583588697}. Best is trial 2 with value: 0.698.
# <ipython-input-46-7f746f6fccb6>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.2),
# <ipython-input-46-7f746f6fccb6>:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# <ipython-input-46-7f746f6fccb6>:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# [I 2025-04-22 08:02:22,656] Trial 5 finished with value: 0.695375 and parameters: {'n_estimators': 335, 'learning_rate': 0.04317007885300663, 'max_depth': 6, 'subsample': 0.6606990829963976, 'colsample_bytree': 0.8874202240369875}. Best is trial 2 with value: 0.698.
# <ipython-input-46-7f746f6fccb6>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.2),
# <ipython-input-46-7f746f6fccb6>:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# <ipython-input-46-7f746f6fccb6>:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# [I 2025-04-22 08:02:23,413] Trial 6 finished with value: 0.696625 and parameters: {'n_estimators': 214, 'learning_rate': 0.038608370507826804, 'max_depth': 6, 'subsample': 0.6323775176618237, 'colsample_bytree': 0.6373079445961926}. Best is trial 2 with value: 0.698.
# <ipython-input-46-7f746f6fccb6>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.2),
# <ipython-input-46-7f746f6fccb6>:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# <ipython-input-46-7f746f6fccb6>:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# [I 2025-04-22 08:02:25,290] Trial 7 finished with value: 0.673875 and parameters: {'n_estimators': 304, 'learning_rate': 0.15981433293687872, 'max_depth': 10, 'subsample': 0.9885768237013985, 'colsample_bytree': 0.9734449201954684}. Best is trial 2 with value: 0.698.
# <ipython-input-46-7f746f6fccb6>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.2),
# <ipython-input-46-7f746f6fccb6>:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# <ipython-input-46-7f746f6fccb6>:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# [I 2025-04-22 08:02:26,271] Trial 8 finished with value: 0.700375 and parameters: {'n_estimators': 404, 'learning_rate': 0.053762869897261346, 'max_depth': 4, 'subsample': 0.9026198029249131, 'colsample_bytree': 0.8698336705585479}. Best is trial 8 with value: 0.700375.
# <ipython-input-46-7f746f6fccb6>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.2),
# <ipython-input-46-7f746f6fccb6>:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# <ipython-input-46-7f746f6fccb6>:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# [I 2025-04-22 08:02:27,078] Trial 9 finished with value: 0.69675 and parameters: {'n_estimators': 235, 'learning_rate': 0.04263282816864247, 'max_depth': 6, 'subsample': 0.728705819369405, 'colsample_bytree': 0.7788638496667208}. Best is trial 8 with value: 0.700375.
# <ipython-input-46-7f746f6fccb6>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.2),
# <ipython-input-46-7f746f6fccb6>:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# <ipython-input-46-7f746f6fccb6>:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# [I 2025-04-22 08:02:28,092] Trial 10 finished with value: 0.69825 and parameters: {'n_estimators': 496, 'learning_rate': 0.010056504064728116, 'max_depth': 3, 'subsample': 0.8938981434633919, 'colsample_bytree': 0.862433746531125}. Best is trial 8 with value: 0.700375.
# <ipython-input-46-7f746f6fccb6>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.2),
# <ipython-input-46-7f746f6fccb6>:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# <ipython-input-46-7f746f6fccb6>:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# [I 2025-04-22 08:02:29,100] Trial 11 finished with value: 0.698 and parameters: {'n_estimators': 500, 'learning_rate': 0.010195022003581472, 'max_depth': 3, 'subsample': 0.8905092100087459, 'colsample_bytree': 0.8781779058927751}. Best is trial 8 with value: 0.700375.
# <ipython-input-46-7f746f6fccb6>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.2),
# <ipython-input-46-7f746f6fccb6>:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# <ipython-input-46-7f746f6fccb6>:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# [I 2025-04-22 08:02:30,079] Trial 12 finished with value: 0.7 and parameters: {'n_estimators': 496, 'learning_rate': 0.08772963960745343, 'max_depth': 3, 'subsample': 0.8861342082941179, 'colsample_bytree': 0.8602328700320145}. Best is trial 8 with value: 0.700375.
# <ipython-input-46-7f746f6fccb6>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.2),
# <ipython-input-46-7f746f6fccb6>:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# <ipython-input-46-7f746f6fccb6>:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# [I 2025-04-22 08:02:31,123] Trial 13 finished with value: 0.6995 and parameters: {'n_estimators': 442, 'learning_rate': 0.10810602977227791, 'max_depth': 4, 'subsample': 0.8760237125860987, 'colsample_bytree': 0.8489327870554909}. Best is trial 8 with value: 0.700375.
# <ipython-input-46-7f746f6fccb6>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.2),
# <ipython-input-46-7f746f6fccb6>:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# <ipython-input-46-7f746f6fccb6>:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# [I 2025-04-22 08:02:32,082] Trial 14 finished with value: 0.699625 and parameters: {'n_estimators': 441, 'learning_rate': 0.08010911389765882, 'max_depth': 4, 'subsample': 0.9688631265018811, 'colsample_bytree': 0.9992346841594373}. Best is trial 8 with value: 0.700375.
# <ipython-input-46-7f746f6fccb6>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.2),
# <ipython-input-46-7f746f6fccb6>:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# <ipython-input-46-7f746f6fccb6>:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# [I 2025-04-22 08:02:36,242] Trial 15 finished with value: 0.695875 and parameters: {'n_estimators': 469, 'learning_rate': 0.18916092501402765, 'max_depth': 4, 'subsample': 0.830875485520723, 'colsample_bytree': 0.8281708284014443}. Best is trial 8 with value: 0.700375.
# <ipython-input-46-7f746f6fccb6>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.2),
# <ipython-input-46-7f746f6fccb6>:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# <ipython-input-46-7f746f6fccb6>:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# [I 2025-04-22 08:02:37,270] Trial 16 finished with value: 0.695875 and parameters: {'n_estimators': 386, 'learning_rate': 0.07646034412614587, 'max_depth': 5, 'subsample': 0.9506497100643083, 'colsample_bytree': 0.9244725414855619}. Best is trial 8 with value: 0.700375.
# <ipython-input-46-7f746f6fccb6>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.2),
# <ipython-input-46-7f746f6fccb6>:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# <ipython-input-46-7f746f6fccb6>:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# [I 2025-04-22 08:02:38,613] Trial 17 finished with value: 0.6905 and parameters: {'n_estimators': 261, 'learning_rate': 0.12067279658566306, 'max_depth': 8, 'subsample': 0.8260370180645171, 'colsample_bytree': 0.9229845216581745}. Best is trial 8 with value: 0.700375.
# <ipython-input-46-7f746f6fccb6>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.2),
# <ipython-input-46-7f746f6fccb6>:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# <ipython-input-46-7f746f6fccb6>:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# [I 2025-04-22 08:02:39,520] Trial 18 finished with value: 0.701125 and parameters: {'n_estimators': 455, 'learning_rate': 0.02665368419331312, 'max_depth': 3, 'subsample': 0.9235203316988269, 'colsample_bytree': 0.6952491788909384}. Best is trial 18 with value: 0.701125.
# <ipython-input-46-7f746f6fccb6>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.2),
# <ipython-input-46-7f746f6fccb6>:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# <ipython-input-46-7f746f6fccb6>:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# [I 2025-04-22 08:02:40,594] Trial 19 finished with value: 0.7015 and parameters: {'n_estimators': 354, 'learning_rate': 0.02293835843806851, 'max_depth': 5, 'subsample': 0.9361954824881094, 'colsample_bytree': 0.6483615813850657}. Best is trial 19 with value: 0.7015.
# <ipython-input-46-7f746f6fccb6>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.2),
# <ipython-input-46-7f746f6fccb6>:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# <ipython-input-46-7f746f6fccb6>:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# [I 2025-04-22 08:02:40,995] Trial 20 finished with value: 0.698125 and parameters: {'n_estimators': 111, 'learning_rate': 0.017576950279694126, 'max_depth': 5, 'subsample': 0.9362199056740914, 'colsample_bytree': 0.6082421936769573}. Best is trial 19 with value: 0.7015.
# <ipython-input-46-7f746f6fccb6>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.2),
# <ipython-input-46-7f746f6fccb6>:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# <ipython-input-46-7f746f6fccb6>:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# [I 2025-04-22 08:02:42,039] Trial 21 finished with value: 0.70275 and parameters: {'n_estimators': 368, 'learning_rate': 0.02743571496455239, 'max_depth': 5, 'subsample': 0.9259380171169862, 'colsample_bytree': 0.6677886557020324}. Best is trial 21 with value: 0.70275.
# <ipython-input-46-7f746f6fccb6>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.2),
# <ipython-input-46-7f746f6fccb6>:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# <ipython-input-46-7f746f6fccb6>:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# [I 2025-04-22 08:02:43,085] Trial 22 finished with value: 0.703875 and parameters: {'n_estimators': 353, 'learning_rate': 0.027162583502817327, 'max_depth': 5, 'subsample': 0.930768357976193, 'colsample_bytree': 0.6764184808888312}. Best is trial 22 with value: 0.703875.
# <ipython-input-46-7f746f6fccb6>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.2),
# <ipython-input-46-7f746f6fccb6>:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# <ipython-input-46-7f746f6fccb6>:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# [I 2025-04-22 08:02:44,074] Trial 23 finished with value: 0.700875 and parameters: {'n_estimators': 352, 'learning_rate': 0.027611508207057583, 'max_depth': 5, 'subsample': 0.9889749792178262, 'colsample_bytree': 0.6654385183594992}. Best is trial 22 with value: 0.703875.
# <ipython-input-46-7f746f6fccb6>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.2),
# <ipython-input-46-7f746f6fccb6>:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# <ipython-input-46-7f746f6fccb6>:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# [I 2025-04-22 08:02:45,303] Trial 24 finished with value: 0.69775 and parameters: {'n_estimators': 276, 'learning_rate': 0.017284781364485677, 'max_depth': 7, 'subsample': 0.8506761062467179, 'colsample_bytree': 0.6698093390748461}. Best is trial 22 with value: 0.703875.
# <ipython-input-46-7f746f6fccb6>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.2),
# <ipython-input-46-7f746f6fccb6>:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# <ipython-input-46-7f746f6fccb6>:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# [I 2025-04-22 08:02:49,050] Trial 25 finished with value: 0.702375 and parameters: {'n_estimators': 304, 'learning_rate': 0.021752902193537964, 'max_depth': 5, 'subsample': 0.7685017972725281, 'colsample_bytree': 0.6041836074700445}. Best is trial 22 with value: 0.703875.
# <ipython-input-46-7f746f6fccb6>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.2),
# <ipython-input-46-7f746f6fccb6>:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# <ipython-input-46-7f746f6fccb6>:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# [I 2025-04-22 08:02:50,547] Trial 26 finished with value: 0.697875 and parameters: {'n_estimators': 302, 'learning_rate': 0.013640050307981995, 'max_depth': 7, 'subsample': 0.7758740569736299, 'colsample_bytree': 0.6021908697731649}. Best is trial 22 with value: 0.703875.
# <ipython-input-46-7f746f6fccb6>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.2),
# <ipython-input-46-7f746f6fccb6>:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# <ipython-input-46-7f746f6fccb6>:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# [I 2025-04-22 08:02:51,353] Trial 27 finished with value: 0.701875 and parameters: {'n_estimators': 261, 'learning_rate': 0.03196832454999053, 'max_depth': 5, 'subsample': 0.7879715940551677, 'colsample_bytree': 0.7132282397182679}. Best is trial 22 with value: 0.703875.
# <ipython-input-46-7f746f6fccb6>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.2),
# <ipython-input-46-7f746f6fccb6>:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# <ipython-input-46-7f746f6fccb6>:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# [I 2025-04-22 08:02:52,999] Trial 28 finished with value: 0.6955 and parameters: {'n_estimators': 326, 'learning_rate': 0.03421213536263501, 'max_depth': 8, 'subsample': 0.7273454694811993, 'colsample_bytree': 0.627753291740133}. Best is trial 22 with value: 0.703875.
# <ipython-input-46-7f746f6fccb6>:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.2),
# <ipython-input-46-7f746f6fccb6>:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
# <ipython-input-46-7f746f6fccb6>:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.6, 1.0),
# [I 2025-04-22 08:02:53,568] Trial 29 finished with value: 0.701625 and parameters: {'n_estimators': 200, 'learning_rate': 0.05971749847316164, 'max_depth': 4, 'subsample': 0.7021203889222177, 'colsample_bytree': 0.7347288742073681}. Best is trial 22 with value: 0.703875.
# Best XGBoost Parameters: {'n_estimators': 353, 'learning_rate': 0.027162583502817327, 'max_depth': 5, 'subsample': 0.930768357976193, 'colsample_bytree': 0.6764184808888312}
#
# Final XGBoost Model Accuracy: 0.6995
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.63      0.67      0.65      3349
#            1       0.75      0.72      0.74      4651
#
#     accuracy                           0.70      8000
#    macro avg       0.69      0.70      0.69      8000
# weighted avg       0.70      0.70      0.70      8000

# %% [markdown]
# making prediction

# %%
# Predict purchase column for Indian dataset
indian_df["purchase"] = final_xgb_model.predict(indian_scaled)

# Check the distribution of predictions
print("\nPurchase Predictions for Indian Cities:")
print(indian_df["purchase"].value_counts(normalize=True))

# Save results
indian_df.to_csv("indian_city_with_predictions.csv", index=False)
print("\nPredictions saved to 'indian_city_with_predictions.csv'")
# Out:
# Purchase Predictions for Indian Cities:
# purchase
# 0    0.515886
# 1    0.484114
# Name: proportion, dtype: float64
#
# Predictions saved to 'indian_city_with_predictions.csv'

# %%
df = pd.read_csv("indian_city_with_predictions.csv")
num_purchases = (df["purchase"] == 1).sum()

print(f"Number of purchases (1s) in Indian dataset: {num_purchases}")
# Out:
# Number of purchases (1s) in Indian dataset: 33888
